# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasMirandaVS/projeto_SQL_analysis/blob/main/DB_SQLite(test).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
pip install -q imdb-sqlite

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # Importando os Dados e Conectando ao banco SQLite

# %%
# Importando os datasets
df_mortes = pd.read_excel('CovidDeaths.xlsx', index_col = 0) 
df_vacina = pd.read_excel('CovidVaccinations.xlsx', index_col = 0)

# %%
df_mortes.head()
# Out:
#          continent     location       date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan 2020-02-24          1.0        1.0
# AFG           Asia  Afghanistan 2020-02-25          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-26          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-27          1.0        0.0
# AFG           Asia  Afghanistan 2020-02-28          1.0        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
# AFG                      NaN           NaN         NaN                  NaN
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
df_vacina.head()
# Out:
#          continent     location       date  new_tests  total_tests  \
# iso_code
# AFG           Asia  Afghanistan 2020-02-24        NaN          NaN
# AFG           Asia  Afghanistan 2020-02-25        NaN          NaN
# AFG           Asia  Afghanistan 2020-02-26        NaN          NaN
# AFG           Asia  Afghanistan 2020-02-27        NaN          NaN
# AFG           Asia  Afghanistan 2020-02-28        NaN          NaN
#
#           total_tests_per_thousand  new_tests_per_thousand  \
# iso_code
# AFG                            NaN                     NaN
# AFG                            NaN                     NaN
# AFG                            NaN                     NaN
# AFG                            NaN                     NaN
# AFG                            NaN                     NaN
#
#           new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# iso_code
# AFG                      NaN                              NaN            NaN
# ...

# %%
con = sqlite3.connect('covid.db')

# %%
'''
for sheet in df_mortes:
  df_mortes[sheet].to_sql(sheet,con,index=False)
con.commit()
con.close()
'''
